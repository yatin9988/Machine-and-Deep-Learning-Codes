# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
### valid convolution -> when padding = 0
### same convolution -> when the applied padding is such that the output volume and input volume have same h and w

# %%
img = cv2.imread('cody2.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img = cv2.resize(img,(100,100))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
### strides -> it is defined as the movement size of a filter across a image
### padding -> adding extra pixels/margin across a im
